# %%
#1) Create an empty dictionary called dog
dog = {}

# %%
#2) Add name, color, breed, legs, age to the dog dictionary
dog = {
    "Name" : "Oliver",
    "Color" : "Brown",
    "Legs" : 4,
    "age" : 5
}

# %%
print(dog)
# Out:
# {'Name': 'Oliver', 'Color': 'Brown', 'Legs': 4, 'age': 5}

# %%
print(dog.keys())
# Out:
# dict_keys(['Name', 'Color', 'Legs', 'age'])

# %%
print(dog.get("Name"))
# Out:
# Oliver

# %%
dog["Breed"] = "German Shepherd"

# %%
dog.items()
# Out:
# dict_items([('Name', 'Oliver'), ('Color', 'Brown'), ('Legs', 4), ('age', 5), ('Breed', 'German Shepherd')])

# %%
print(dog)
# Out:
# {'Name': 'Oliver', 'Color': 'Brown', 'Legs': 4, 'age': 5, 'Breed': 'German Shepherd'}

# %%
#3) Create a student dictionary and add first_name, last_name, gender, age, marital status, skills, country, city and address as keys for the dictionary

student = {
    "first_name" : "Emarld",
    "last_name" : "Stone",
    "gender" : "Female",
    "age" : 25,
    "martial status" : "Unmarried",
    "skills" :["SQL", "Python", "Power Bi","MS Excel", "Statistics", "Data Analysis"],
    "address":{
        "Country" : "USA",
        "City" : "San Jose",
        "Pincode" : 95101              
    }
}

# %%
print(student)
# Out:
# {'first_name': 'Emarld', 'last_name': 'Stone', 'gender': 'Female', 'age': 25, 'martial status': 'Unmarried', 'skills': ['SQL', 'Python', 'Power Bi', 'MS Excel', 'Statistics', 'Data Analysis'], 'address': {'Country': 'USA', 'City': 'San Jose', 'Pincode': 95101}}

# %%
#4) Get the length of the student dictionary
len(student)
# Out:
# 7

# %%
#5) Get the value of skills and check the data type, it should be a list
for s in student["skills"]:
    print("Skills :",s, ",", "Datatype:", type(student["skills"]))
# Out:
# Skills : SQL , Datatype: <class 'list'>
# Skills : Python , Datatype: <class 'list'>
# Skills : Power Bi , Datatype: <class 'list'>
# Skills : MS Excel , Datatype: <class 'list'>
# Skills : Statistics , Datatype: <class 'list'>
# Skills : Data Analysis , Datatype: <class 'list'>

# %%
print("Datatype of Skills in Student:", type(student["skills"]))
# Out:
# Datatype of Skills in Student: <class 'list'>

# %%
#6) Modify the skills values by adding one or two or more skills

sk = ["Tableau", "Machine Learning", "Automation", "Web Scrapping"]

for skill in sk:
    student["skills"].append(skill)

# %%
print(student)
# Out:
# {'first_name': 'Emarld', 'last_name': 'Stone', 'gender': 'Female', 'age': 25, 'martial status': 'Unmarried', 'skills': ['SQL', 'Python', 'Power Bi', 'MS Excel', 'Statistics', 'Data Analysis', 'Tableau', 'Machine Learning', 'Automation', 'Web Scrapping'], 'address': {'Country': 'USA', 'City': 'San Jose', 'Pincode': 95101}}

# %%
student_skill_lst = student["skills"].copy()

# %%
student_skill_lst
# Out:
# ['SQL',
#  'Python',
#  'Power Bi',
#  'MS Excel',
#  'Statistics',
#  'Data Analysis',
#  'Tableau',
#  'Machine Learning',
#  'Automation',
#  'Web Scrapping']

# %%
#7) Get the dictionary keys as a list

student_key = student.keys()
student_key
# Out:
# dict_keys(['first_name', 'last_name', 'gender', 'age', 'martial status', 'skills', 'address'])

# %%
#8) Get the dictionary values as a list

student_val = student.values()
student_val
# Out:
# dict_values(['Emarld', 'Stone', 'Female', 25, 'Unmarried', ['SQL', 'Python', 'Power Bi', 'MS Excel', 'Statistics', 'Data Analysis', 'Tableau', 'Machine Learning', 'Automation', 'Web Scrapping'], {'Country': 'USA', 'City': 'San Jose', 'Pincode': 95101}])

# %%
#9) Change the dictionary to a list of tuples using items() method

student.items()
# Out:
# dict_items([('first_name', 'Emarld'), ('last_name', 'Stone'), ('gender', 'Female'), ('age', 25), ('martial status', 'Unmarried'), ('skills', ['SQL', 'Python', 'Power Bi', 'MS Excel', 'Statistics', 'Data Analysis', 'Tableau', 'Machine Learning', 'Automation', 'Web Scrapping']), ('address', {'Country': 'USA', 'City': 'San Jose', 'Pincode': 95101})])

# %%
#10) Delete one of the items in the dictionary

dog.pop("age")
# Out:
# 5

# %%
print(dog)
# Out:
# {'Name': 'Oliver', 'Color': 'Brown', 'Legs': 4, 'Breed': 'German Shepherd'}

# %%
#11) Delete one of the dictionaries

del dog

# %%
print(dog)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(dog)
#
# NameError: name 'dog' is not defined
