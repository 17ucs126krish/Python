# %% [markdown]
# # Exercises: Level 1

# %%
#1) Create an empty tuple
t = ()

# %%
#2) Create a tuple containing names of your sisters and your brothers (imaginary siblings are fine)

sisters = ("Casandra", 'Emarld stone','Nova gold','Starfire')

brothers = ("Bruce Wayne","Clark Kent","Peter Parker","Sherlock Homes")

# %%
#3) Join brothers and sisters tuples and assign it to siblings
sibilings = sisters + brothers

# %%
sibilings
# Out:
# ('Casandra',
#  'Emarld stone',
#  'Nova gold',
#  'Starfire',
#  'Bruce Wayne',
#  'Clark Kent',
#  'Peter Parker',
#  'Sherlock Homes')

# %%
#4) How many siblings do you have?
sib_len = len(sibilings)
print(f'I have {sib_len} sibilings')
# Out:
# I have 8 sibilings

# %%
#5) Modify the siblings tuple and add the name of your father and mother and assign it to family_members

family_members = list(sibilings)

# %%
family_members.insert(0,'Charles Xavier')

# %%
family_members.insert(1, "Diana")

# %%
print(family_members)
# Out:
# ['Charles Xavier', 'Diana', 'Casandra', 'Emarld stone', 'Nova gold', 'Starfire', 'Bruce Wayne', 'Clark Kent', 'Peter Parker', 'Sherlock Homes']

# %%
family_members = tuple(family_members)

# %%
type(family_members)
# Out:
# tuple

# %% [markdown]
# # Exercises: Level 2

# %%
#1) Unpack siblings and parents from family_members
family_members
# Out:
# ('Charles Xavier',
#  'Diana',
#  'Casandra',
#  'Emarld stone',
#  'Nova gold',
#  'Starfire',
#  'Bruce Wayne',
#  'Clark Kent',
#  'Peter Parker',
#  'Sherlock Homes')

# %%
(father, mother, *sibilings) = family_members

# %%
print(f"Father:{father}")
print(f"Mother:{mother}")
print(f"Sibilings:{sibilings}")
# Out:
# Father:Charles Xavier
# Mother:Diana
# Sibilings:['Casandra', 'Emarld stone', 'Nova gold', 'Starfire', 'Bruce Wayne', 'Clark Kent', 'Peter Parker', 'Sherlock Homes']

# %%
type(family_members)
# Out:
# tuple

# %%
#2) Create fruits, vegetables and animal products tuples. Join the three tuples and assign it to a variable called food_stuff_tp.

fruits = ("Apple","Pineapple","Watermelon","Banana")
vegetables = ("Carrots","Soya", "Garbanzo Beans","Broccoli")
animal_products = ("Milk","Ghee","Butter","Eggs")

# %%
food_stuff_tp = fruits + vegetables +  animal_products

# %%
print(food_stuff_tp)
# Out:
# ('Apple', 'Pineapple', 'Watermelon', 'Banana', 'Carrots', 'Soya', 'Garbanzo Beans', 'Broccoli', 'Milk', 'Ghee', 'Butter', 'Eggs')

# %%
#3) Change the about food_stuff_tp tuple to a food_stuff_lt list
food_stuff_lt = list(food_stuff_tp)

# %%
type(food_stuff_lt)
# Out:
# list

# %%
#4) Slice out the middle item or items from the food_stuff_tp tuple or food_stuff_lt list.

del food_stuff_lt[7]

# %%
print(food_stuff_lt)
# Out:
# ['Apple', 'Pineapple', 'Watermelon', 'Banana', 'Carrots', 'Soya', 'Garbanzo Beans', 'Milk', 'Ghee', 'Butter', 'Eggs']

# %%
#5)  Slice out the first three items and the last three items from food_stuff_lt list

first_three_items = food_stuff_lt[0:3]

# %%
first_three_items
# Out:
# ['Apple', 'Pineapple', 'Watermelon']

# %%
last_three_items = food_stuff_lt[-3:]

# %%
last_three_items
# Out:
# ['Ghee', 'Butter', 'Eggs']

# %%
#6) Delete the food_stuff_tp tuple completely
del food_stuff_tp

# %%
#7) Check if an item exists in tuple:
'''
-> Check if 'Estonia' is a nordic country

-> Check if 'Iceland' is a nordic country
'''

nordic_countries = ('Denmark', 'Finland','Iceland', 'Norway', 'Sweden')

# %%
#i) Check if 'Estonia' is a nordic country

"Estonia" in nordic_countries
# Out:
# False

# %%
#ii) heck if 'Iceland' is a nordic country

"Iceland" in nordic_countries
# Out:
# True
